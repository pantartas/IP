# %%
# %%javascript
#
# window.scroll_flag = true
# window.scroll_exit = false
# window.scroll_delay = 100
#
# $(".output_scroll").each(function() {
#     $(this)[0].scrollTop = $(this)[0].scrollHeight;
# });
#
# function callScrollToBottom() {
#     setTimeout(scrollToBottom, window.scroll_delay);
# }
#
# function scrollToBottom() {
#     if (window.scroll_exit) {
#         return;
#     }
#     if (!window.scroll_flag) {
#         callScrollToBottom();
#         return;
#     };
#
#     $(".output_scroll").each(function() {
#         if (!$(this).attr('scroll_checkbox')){
#             window.scroll_flag = true;
#             $(this).attr('scroll_checkbox',true);
#             var div = document.createElement('div');
#             var checkbox = document.createElement('input');
#             checkbox.type = "checkbox";
#             checkbox.onclick = function(){window.scroll_flag = checkbox.checked}
#             checkbox.checked = "checked"
#             div.append("Auto-Scroll-To-Bottom: ");
#             div.append(checkbox);
#             $(this).parent().before(div);
#         }
#
#         $(this)[0].scrollTop = $(this)[0].scrollHeight;
#     });
#     callScrollToBottom();
# }
# scrollToBottom();

# %%
#import necessary libraries
import os
import IPython
import librosa as lr
import numpy as np
from datetime import datetime
from packaging import version
import tensorboard
import keras
from keras import layers
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt
from librosa import display
from tensorflow.keras.layers import Conv2D,MaxPooling2D,UpSampling2D,Flatten,Dense,Activation,Conv2DTranspose
import time

#LOG_DIR = f'{int(time.time())}'

path = 'C:/Users/erikv/Desktop/IP/samples/' #path where the samples are stored'''
dirs = os.listdir(path) #open the directory using os library'''

def rosaspec(sound, NFFT): #defined functions for extracting the spectogram of a sound wave'''
    sound = np.concatenate((np.zeros(int(NFFT/2)),sound,np.zeros(int(NFFT/2))))
    spec_c = lr.stft(sound, n_fft=NFFT, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)
    return np.concatenate((np.expand_dims(np.real(spec_c),2),np.expand_dims(np.imag(spec_c),2)),axis=2)

def irosaspec(spec,NFFT): #defined function for extracting a soundwave from a spectogram'''
    spec_c = spec[:,:,0].squeeze() + 1j* spec[:,:,1].squeeze()
    return lr.istft(spec_c, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)[int(NFFT/2):-int(NFFT/2)]

# %%
NFFT =  int(1021/2) #selection of the NFFT, allows the modification of the sie of 2nd array dimension'''

batchsize = 1000 #len(dirs) #selection of the batch size'''
testsize = int(0.2*batchsize) #selection of the test batch file'''

yoriginal1,sroriginal1 = lr.load(path+dirs[9],sr=4*8150) #open the audio file (in this case the 
                                                         #test one) using the librosa library'''
yoriginal1 = yoriginal1[0:int(len(yoriginal1)/2)] #cropping of the loaded file to half the length for testing purposes'''
#originalspect = lr.stft(yoriginal1, n_fft=NFFT, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)
asignal = np.array([rosaspec(yoriginal1,NFFT)]) #spectogram extraction from the file'''
audio = asignal#/asignal.max() #normalized values to be between 0 and 1
test= audio


print (test.shape,test.max())
# Out:
# (1, 256, 256, 2) 81.70637530442946

# %%
IPython.display.display(IPython.display.Audio(yoriginal1,rate = sroriginal1)) #check if the audio has been correctly loaded
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
processed = np.zeros([batchsize, 256, 256, 2]) #prepare a 0 array. The processes is a loop using the same 
                                               #procedure as explained before
for i in range(batchsize):
    yoriginal,sroriginal = lr.load(path+dirs[i],sr=4*8150) 
    yoriginal = yoriginal[0:int(len(yoriginal)/2)]
    #originalspect = lr.stft(yoriginal, n_fft=NFFT, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)
    asignal = np.array([rosaspec(yoriginal,NFFT)])
    audio = asignal#/asignal.max()
    processed[i] = audio

print (asignal.shape,processed.shape) #we have now an array of 100 files in dimensions 256x256x2
# Out:
# (1, 256, 256, 2) (1000, 256, 256, 2)

# %%
IPython.display.display(IPython.display.Audio(yoriginal,rate = sroriginal1)) #check if the loading has been successful
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
device = 'cuda'
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU'))) #check if keras is using GPU optimization
if test[0,20,20,0] == processed[9,20,20,0]: #if these two numbers are the same the files are coincident and correct loading
    print ('--------------loading correct--------------')
else:
    print('--------------loading failed. check coordinates--------------')
# Out:
# Num GPUs Available:  1
# --------------loading correct--------------

# %%
#the autoencoder is composed of 4 encoding layers and 4 decding layers

encoder_input = keras.Input(shape=(256, 256, 2), name="original audio")
x = layers.Conv2D(8, 3, activation="relu")(encoder_input)
x = layers.MaxPooling2D(2)(x)
x = layers.Conv2D(16, 3, activation="relu")(x)
x = layers.MaxPooling2D(2)(x)
x = layers.Conv2D(32, 3, activation="relu")(x)
x = layers.MaxPooling2D(2)(x)
encoder_output = layers.Conv2D(64, 3, activation=None)(x) #the file is reduced to 80x80x16

encoder = keras.Model(encoder_input, encoder_output, name="encoder")
encoder.summary()

decoder_input = keras.Input(shape=(28, 28 ,64), name="encoded audio")
x = layers.Conv2DTranspose(32, 3, activation="relu")(decoder_input)
x = layers.UpSampling2D(2)(x)
x = layers.Conv2DTranspose(16, 3, activation="relu")(x)
x = layers.UpSampling2D(2)(x)
x = layers.Conv2DTranspose(8, 3, activation="relu")(x)
x = layers.UpSampling2D(2)(x)
x = layers.Conv2DTranspose(4, 3, activation="relu")(x)

decoder_output = layers.Conv2DTranspose(2, 3, activation=None)(x) #this last layer does not have an activation method

decoder = keras.Model(decoder_input, decoder_output, name="decoder")
decoder.summary()

autoencoder_input = keras.Input(shape=(256, 256, 2), name="img")
encoded_img = encoder(autoencoder_input)
decoded_img = decoder(encoded_img)
autoencoder = keras.Model(autoencoder_input, decoded_img, name="autoencoder")
autoencoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# original audio (InputLayer)  [(None, 256, 256, 2)]     0
# _________________________________________________________________
# conv2d_93 (Conv2D)           (None, 254, 254, 8)       152
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 127, 127, 8)       0
# _________________________________________________________________
# conv2d_94 (Conv2D)           (None, 125, 125, 16)      1168
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_95 (Conv2D)           (None, 60, 60, 32)        4640
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_96 (Conv2D)           (None, 28, 28, 64)        18496
# =================================================================
# Total params: 24,456
# Trainable params: 24,456
# Non-trainable params: 0
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoded audio (InputLayer)   [(None, 28, 28, 64)]      0
# _________________________________________________________________
# conv2d_transpose_93 (Conv2DT (None, 30, 30, 32)        18464
# _________________________________________________________________
# up_sampling2d_30 (UpSampling (None, 60, 60, 32)        0
# _________________________________________________________________
# conv2d_transpose_94 (Conv2DT (None, 62, 62, 16)        4624
# _________________________________________________________________
# up_sampling2d_31 (UpSampling (None, 124, 124, 16)      0
# _________________________________________________________________
# conv2d_transpose_95 (Conv2DT (None, 126, 126, 8)       1160
# _________________________________________________________________
# up_sampling2d_32 (UpSampling (None, 252, 252, 8)       0
# _________________________________________________________________
# conv2d_transpose_96 (Conv2DT (None, 254, 254, 4)       292
# _________________________________________________________________
# conv2d_transpose_97 (Conv2DT (None, 256, 256, 2)       74
# =================================================================
# Total params: 24,614
# Trainable params: 24,614
# Non-trainable params: 0
# _________________________________________________________________
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# img (InputLayer)             [(None, 256, 256, 2)]     0
# _________________________________________________________________
# encoder (Functional)         (None, 28, 28, 64)        24456
# _________________________________________________________________
# decoder (Functional)         (None, 256, 256, 2)       24614
# =================================================================
# Total params: 49,070
# Trainable params: 49,070
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adam', 
                  loss='mean_squared_error',
                  metrics=["mean_squared_error"]) #the autoencoder is optimizwed using adam and the loss and metrics are
                                                  #mean squared error
autoencoder.fit(processed,processed,
                epochs=50,
                batch_size=10,
                shuffle=True,
                validation_split=0.2) #it is trained using a 20% validations. So from the 100 files batch, 80 are for 
                                      #training and 20 are for validation purposes
# Out:
# Epoch 1/50
# 80/80 [==============================] - 6s 45ms/step - loss: 5.1075 - mean_squared_error: 5.1075 - val_loss: 2.3572 - val_mean_squared_error: 2.3572
# Epoch 2/50
# 80/80 [==============================] - 3s 39ms/step - loss: 4.6559 - mean_squared_error: 4.6559 - val_loss: 2.3656 - val_mean_squared_error: 2.3656
# Epoch 3/50
# 80/80 [==============================] - 3s 39ms/step - loss: 4.2415 - mean_squared_error: 4.2415 - val_loss: 2.3605 - val_mean_squared_error: 2.3605
# Epoch 4/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.1569 - mean_squared_error: 4.1569 - val_loss: 2.3595 - val_mean_squared_error: 2.3595
# Epoch 5/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.1428 - mean_squared_error: 4.1428 - val_loss: 2.3594 - val_mean_squared_error: 2.3594
# Epoch 6/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.1383 - mean_squared_error: 4.1383 - val_loss: 2.3607 - val_mean_squared_error: 2.3607
# Epoch 7/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.1365 - mean_squared_error: 4.1365 - val_loss: 2.3631 - val_mean_squared_error: 2.3631
# Epoch 8/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.1434 - mean_squared_error: 4.1434 - val_loss: 2.3608 - val_mean_squared_error: 2.3608
# Epoch 9/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.1301 - mean_squared_error: 4.1301 - val_loss: 2.3614 - val_mean_squared_error: 2.3614
# Epoch 10/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.1272 - mean_squared_error: 4.1272 - val_loss: 2.3601 - val_mean_squared_error: 2.3601
# Epoch 11/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.1236 - mean_squared_error: 4.1236 - val_loss: 2.3610 - val_mean_squared_error: 2.3610
# Epoch 12/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.1245 - mean_squared_error: 4.1245 - val_loss: 2.3602 - val_mean_squared_error: 2.3602
# Epoch 13/50
# 80/80 [==============================] - 3s 41ms/step - loss: 4.1208 - mean_squared_error: 4.1208 - val_loss: 2.3610 - val_mean_squared_error: 2.3610
# Epoch 14/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.1229 - mean_squared_error: 4.1229 - val_loss: 2.3601 - val_mean_squared_error: 2.3601
# Epoch 15/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.1272 - mean_squared_error: 4.1272 - val_loss: 2.3588 - val_mean_squared_error: 2.3588
# Epoch 16/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.1227 - mean_squared_error: 4.1227 - val_loss: 2.3612 - val_mean_squared_error: 2.3612
# Epoch 17/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.1173 - mean_squared_error: 4.1173 - val_loss: 2.3603 - val_mean_squared_error: 2.3603
# Epoch 18/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.1258 - mean_squared_error: 4.1258 - val_loss: 2.3607 - val_mean_squared_error: 2.3607
# Epoch 19/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.1472 - mean_squared_error: 4.1472 - val_loss: 2.3622 - val_mean_squared_error: 2.3622
# Epoch 20/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.1179 - mean_squared_error: 4.1179 - val_loss: 2.3615 - val_mean_squared_error: 2.3615
# Epoch 21/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.1137 - mean_squared_error: 4.1137 - val_loss: 2.3617 - val_mean_squared_error: 2.3617
# Epoch 22/50
# 80/80 [==============================] - 3s 41ms/step - loss: 4.1151 - mean_squared_error: 4.1151 - val_loss: 2.3611 - val_mean_squared_error: 2.3611
# Epoch 23/50
# 80/80 [==============================] - 3s 41ms/step - loss: 4.1137 - mean_squared_error: 4.1137 - val_loss: 2.3614 - val_mean_squared_error: 2.3614
# Epoch 24/50
# 80/80 [==============================] - 3s 41ms/step - loss: 4.1124 - mean_squared_error: 4.1124 - val_loss: 2.3592 - val_mean_squared_error: 2.3592
# Epoch 25/50
# 80/80 [==============================] - 3s 41ms/step - loss: 4.1098 - mean_squared_error: 4.1098 - val_loss: 2.3606 - val_mean_squared_error: 2.3606
# Epoch 26/50
# 80/80 [==============================] - 3s 41ms/step - loss: 4.1012 - mean_squared_error: 4.1012 - val_loss: 2.3611 - val_mean_squared_error: 2.3611
# Epoch 27/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.0991 - mean_squared_error: 4.0991 - val_loss: 2.3604 - val_mean_squared_error: 2.3604
# Epoch 28/50
# 80/80 [==============================] - 3s 41ms/step - loss: 4.1218 - mean_squared_error: 4.1218 - val_loss: 2.3615 - val_mean_squared_error: 2.3615
# Epoch 29/50
# 80/80 [==============================] - 3s 41ms/step - loss: 4.0859 - mean_squared_error: 4.0859 - val_loss: 2.3586 - val_mean_squared_error: 2.3586
# Epoch 30/50
# 80/80 [==============================] - 3s 41ms/step - loss: 4.0785 - mean_squared_error: 4.0785 - val_loss: 2.3590 - val_mean_squared_error: 2.3590
# Epoch 31/50
# 80/80 [==============================] - 3s 42ms/step - loss: 4.0757 - mean_squared_error: 4.0757 - val_loss: 2.3580 - val_mean_squared_error: 2.3580
# Epoch 32/50
# 80/80 [==============================] - 3s 42ms/step - loss: 4.0760 - mean_squared_error: 4.0760 - val_loss: 2.3583 - val_mean_squared_error: 2.3583
# Epoch 33/50
# 80/80 [==============================] - 3s 42ms/step - loss: 4.0706 - mean_squared_error: 4.0706 - val_loss: 2.3589 - val_mean_squared_error: 2.3589
# Epoch 34/50
# 80/80 [==============================] - 3s 40ms/step - loss: 4.0692 - mean_squared_error: 4.0692 - val_loss: 2.3569 - val_mean_squared_error: 2.3569
# Epoch 35/50
# 80/80 [==============================] - 3s 42ms/step - loss: 4.0687 - mean_squared_error: 4.0687 - val_loss: 2.3593 - val_mean_squared_error: 2.3593
# Epoch 36/50
# 80/80 [==============================] - 3s 42ms/step - loss: 4.0695 - mean_squared_error: 4.0695 - val_loss: 2.3590 - val_mean_squared_error: 2.3590
# Epoch 37/50
# 80/80 [==============================] - 3s 41ms/step - loss: 4.0890 - mean_squared_error: 4.0890 - val_loss: 2.3572 - val_mean_squared_error: 2.3572
# Epoch 38/50
# 80/80 [==============================] - 3s 41ms/step - loss: 4.0626 - mean_squared_error: 4.0626 - val_loss: 2.3571 - val_mean_squared_error: 2.3571 - mean_s
# Epoch 39/50
# 80/80 [==============================] - 3s 41ms/step - loss: 4.0593 - mean_squared_error: 4.0593 - val_loss: 2.3572 - val_mean_squared_error: 2.3572
# Epoch 40/50
# 80/80 [==============================] - 3s 41ms/step - loss: 4.0603 - mean_squared_error: 4.0603 - val_loss: 2.3584 - val_mean_squared_error: 2.3584
# Epoch 41/50
# 80/80 [==============================] - 3s 41ms/step - loss: 4.0507 - mean_squared_error: 4.0507 - val_loss: 2.3580 - val_mean_squared_error: 2.3580
# Epoch 42/50
# 80/80 [==============================] - 3s 42ms/step - loss: 4.0431 - mean_squared_error: 4.0431 - val_loss: 2.3536 - val_mean_squared_error: 2.3536
# Epoch 43/50
# 79/80 [============================>.] - ETA: 0s - loss: 4.0272 - mean_squared_error: 4.0272

# %%
decoded_array = np.array(autoencoder(test)) #a sample file is runned through the autoencoder
decoded_audio = irosaspec(decoded_array[0],NFFT) #the output array is transformed into audio using the reverse spectogram fnct.

deprobe = irosaspec(processed[9],NFFT) #this is just the sample file runned directly from the processed array NOT the autoenc.

#noisy = yoriginal+np.random.normal(0,0.01,64000)
#ennoisy = rosaspec(noisy, NFFT)
#denoisy = irosaspec(ennoisy,NFFT)
print(decoded_array.shape,decoded_audio.shape,deprobe.shape)
print(decoded_audio[400],deprobe[400])
plt.figure()
plt.subplot(1, 2, 2) 
lr.display.waveplot(y=decoded_audio,sr=sroriginal1)
plt.subplot(1, 2, 1) 
lr.display.waveplot(y=yoriginal1,sr=sroriginal1)
plt.show()

#IPython.display.display(IPython.display.Audio(file))
IPython.display.display(IPython.display.Audio(deprobe,rate = sroriginal))
#IPython.display.display(IPython.display.Audio(noisy,rate=sroriginal))
#IPython.display.display(IPython.display.Audio(denoisy,rate=sroriginal))
IPython.display.display(IPython.display.Audio(decoded_audio,rate=sroriginal))
# Out:
# (1, 256, 256, 2) (65025,) (65025,)
# 0.009069115 0.051347512751817696
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
encoded_array = encoder(test)
encoded_array
# Out:
# <tf.Tensor: shape=(1, 80, 80, 64), dtype=float32, numpy=
# array([[[[0.00000000e+00, 0.00000000e+00, 8.88219833e+00, ...,
#           3.21911931e+00, 2.09728851e+01, 6.77881861e+00],
#          [8.29132855e-01, 1.42069111e+01, 0.00000000e+00, ...,
#           2.62937050e+01, 1.10293665e+01, 1.40658188e+01],
#          [1.10255928e+01, 1.48785734e+01, 0.00000000e+00, ...,
#           3.30265880e+00, 0.00000000e+00, 5.44991732e+00],
#          ...,
#          [0.00000000e+00, 1.78576875e+00, 3.59359458e-02, ...,
#           2.17136931e+00, 1.84202945e+00, 2.03786993e+00],
#          [0.00000000e+00, 1.18344620e-01, 5.13677645e+00, ...,
#           1.31172073e+00, 1.50830758e+00, 0.00000000e+00],
#          [0.00000000e+00, 2.98698592e+00, 6.61337996e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 2.77210236e+00]],
#
#         [[7.20693398e+00, 3.28745055e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 2.29155040e+00],
#          [4.32349491e+00, 4.35678661e-03, 0.00000000e+00, ...,
#           1.40331089e+00, 1.09355080e+00, 6.11551762e+00],
#          [3.64417434e+00, 4.86774385e-01, 0.00000000e+00, ...,
#           9.85830402e+00, 3.39329433e+00, 1.17157650e+00],
#          ...,
#          [0.00000000e+00, 2.40277156e-01, 0.00000000e+00, ...,
#           5.49258813e-02, 1.15439616e-01, 3.30350071e-01],
#          [0.00000000e+00, 4.93751228e-01, 0.00000000e+00, ...,
#           0.00000000e+00, 3.04989755e-01, 4.09799278e-01],
#          [0.00000000e+00, 2.04369247e-01, 0.00000000e+00, ...,
#           8.49418163e-01, 2.32916653e-01, 0.00000000e+00]],
#
#         [[4.52541888e-01, 1.89915895e+00, 0.00000000e+00, ...,
#           3.70453215e+00, 2.39623880e+00, 1.98946977e+00],
#          [0.00000000e+00, 3.18095589e+00, 0.00000000e+00, ...,
#           2.84110117e+00, 1.31655550e+00, 2.78431034e+00],
#          [0.00000000e+00, 2.30669069e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 1.04602373e+00, 1.73756433e+00],
#          ...,
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01],
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01],
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01]],
#
#         ...,
#
#         [[6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01],
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01],
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01],
#          ...,
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01],
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01],
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01]],
#
#         [[6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01],
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01],
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01],
#          ...,
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01],
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01],
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01]],
#
#         [[6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01],
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01],
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01],
#          ...,
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01],
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01],
#          [6.06975406e-02, 1.74359173e-01, 1.04570873e-01, ...,
#           1.02664396e-01, 0.00000000e+00, 1.10898890e-01]]]],
#       dtype=float32)>

# %%
print(decoded_array.shape)
# Out:
# (100, 256, 256, 2)

# %%
from scipy.signal import butter, lfilter, freqz

def butter_lowpass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return b, a

def butter_lowpass_filter(data, cutoff, fs, order=5):
    b, a = butter_lowpass(cutoff, fs, order=order)
    y = lfilter(b, a, data)
    return y


# Setting standard filter requirements.
order = 6
fs = 30.0       
cutoff = 8

b, a = butter_lowpass(cutoff, fs, order)

filtered1 = butter_lowpass_filter(yoriginal1, cutoff, fs, order)
filtered = butter_lowpass_filter(decoded_audio, cutoff, fs, order)
plt.figure()
plt.subplot(1, 2, 2) 
lr.display.waveplot(y=filtered,sr=sroriginal)
plt.subplot(1, 2, 1) 
lr.display.waveplot(y=yoriginal1,sr=sroriginal)
plt.show()

IPython.display.display(IPython.display.Audio(yoriginal1,rate=sroriginal))
IPython.display.display(IPython.display.Audio(filtered,rate=sroriginal))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio.max(), audio.min()
# Out:
# (1.0, -0.856759766190995)

# %%
print(yoriginal.shape)
print(enprobe.shape)
print(deprobe.shape)
print(decoded_array.shape)
print(decoded_audio.shape)
# Out:
# (64000,)
# (504, 128, 2)
# (63881,)
# (504, 128, 2)
# (63881,)

# %%
# Out:
# (1.0, -0.7587283885818327)

# %%
i = 2
j = 4
while i<25600/2:
    NFFT = i
    file = 'C:/Users/erikv/Desktop/IP/samples/bass_electronic_027-056-050.wav'

    yoriginal,sroriginal = lr.load(file,sr=None)
    orginalspect = lr.stft(yoriginal, n_fft=NFFT, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)
    audio = np.array([rosaspec(yoriginal,NFFT)])

    numbers = audio.shape
    x = numbers[1]
    y = numbers[2]
    if x%j == 0 and y%j == 0:
            print (i)
    i=i+2
# Out:
# 110
# 126
# 134
# 166
# 174
# 182
# 254
# 286
# 294
# 302
# 334
# 382
# 406
# 422
# 478
# 486
# 494
# 518
# 526
# 534
# 582
# 606
# 630
# 654
# 670
# 766
# 782
# 822
# 846
# 870
# 894
# 918
# 942
# 974
# 1006
# 1038
# 1070
# 1110
# 1150
# 1190
# 1238
# 1286
# 1334
# 1342
# 1398
# 1406
# 1462
# 1470
# 1526
# 1534
# 1542
# 1606
# 1614
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5012/1441324705.py in <module>
#       7     yoriginal,sroriginal = lr.load(file,sr=None)
#       8     orginalspect = lr.stft(yoriginal, n_fft=NFFT, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)
# ----> 9     audio = np.array([rosaspec(yoriginal,NFFT)])
#      10
#      11     numbers = audio.shape
#
# ~\AppData\Local\Temp/ipykernel_5012/3004960298.py in rosaspec(sound, NFFT)
#       6 def rosaspec(sound, NFFT):
#       7     sound = np.concatenate((np.zeros(int(NFFT/2)),sound,np.zeros(int(NFFT/2))))
# ----> 8     spec_c = lr.stft(sound, n_fft=NFFT, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)
#       9     return np.concatenate((np.expand_dims(np.real(spec_c),2),np.expand_dims(np.imag(spec_c),2)),axis=2)
#      10
#
# C:\ProgramData\Anaconda3\lib\site-packages\librosa\core\spectrum.py in stft(y, n_fft, hop_length, win_length, window, center, dtype, pad_mode)
#     255         bl_t = min(bl_s + n_columns, stft_matrix.shape[1])
#     256
# --> 257         stft_matrix[:, bl_s:bl_t] = fft.rfft(
#     258             fft_window * y_frames[:, bl_s:bl_t], axis=0
#     259         )
#
# KeyboardInterrupt:
