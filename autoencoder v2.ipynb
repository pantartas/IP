# %%
# %%javascript
#
# window.scroll_flag = true
# window.scroll_exit = false
# window.scroll_delay = 100
#
# $(".output_scroll").each(function() {
#     $(this)[0].scrollTop = $(this)[0].scrollHeight;
# });
#
# function callScrollToBottom() {
#     setTimeout(scrollToBottom, window.scroll_delay);
# }
#
# function scrollToBottom() {
#     if (window.scroll_exit) {
#         return;
#     }
#     if (!window.scroll_flag) {
#         callScrollToBottom();
#         return;
#     };
#
#     $(".output_scroll").each(function() {
#         if (!$(this).attr('scroll_checkbox')){
#             window.scroll_flag = true;
#             $(this).attr('scroll_checkbox',true);
#             var div = document.createElement('div');
#             var checkbox = document.createElement('input');
#             checkbox.type = "checkbox";
#             checkbox.onclick = function(){window.scroll_flag = checkbox.checked}
#             checkbox.checked = "checked"
#             div.append("Auto-Scroll-To-Bottom: ");
#             div.append(checkbox);
#             $(this).parent().before(div);
#         }
#
#         $(this)[0].scrollTop = $(this)[0].scrollHeight;
#     });
#     callScrollToBottom();
# }
# scrollToBottom();

# %%
import librosa as lr
import numpy as np
NFFT = int(1006)
file = 'C:/Users/erikv/Desktop/IP/samples/keyboard_electronic_002-067-075.wav'

def rosaspec(sound, NFFT):
    sound = np.concatenate((np.zeros(int(NFFT/2)),sound,np.zeros(int(NFFT/2))))
    spec_c = lr.stft(sound, n_fft=NFFT, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)
    return np.concatenate((np.expand_dims(np.real(spec_c),2),np.expand_dims(np.imag(spec_c),2)),axis=2)



def irosaspec(spec,NFFT):
    spec_c = spec[:,:,0].squeeze() + 1j* spec[:,:,1].squeeze()
    return lr.istft(spec_c, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)[int(NFFT/2):-int(NFFT/2)]
#use a rectangular window.

yoriginal,sroriginal = lr.load(file,sr=None)
#yoriginal = np.random.normal(0,0.1,64000)
originalspect = lr.stft(yoriginal, n_fft=NFFT, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)
asignal = np.array([rosaspec(yoriginal,NFFT)])
audio = asignal/asignal.max()



print(audio.shape, sroriginal)
# Out:
# (1, 504, 128, 2) 16000

# %%
import keras
from keras import layers
from keras import regularizers
import tensorflow as tf
device = 'cuda'

# %%
input_shape = (audio.shape)
k = 2

inp = keras.Input(shape=(input_shape[1],input_shape[2],input_shape[3]))

x = layers.Conv2D(4, (3,3), activation='relu', padding='same')(inp)
#x = layers.MaxPooling2D((k, k), padding='same')(x)
#x = layers.Conv2D(64, (3,3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((k, k), padding='same')(x)

x = layers.Conv2D(4,(3,3), activation='relu',padding='same')(encoded)
#x = layers.UpSampling2D((k, k))(x)
#x = layers.Conv2D(16,(3,3), activation='relu',padding='same')(x)
x = layers.UpSampling2D((k, k))(x)
decoded = layers.Conv2D(2, (3, 3), activation='relu', padding='same')(x)




print(encoded.shape)
print(decoded.shape)
print(audio.shape)
# Out:
# (None, 252, 64, 4)
# (None, 504, 128, 2)
# (1, 504, 128, 2)

# %%
autoencoder = keras.Model(inp, decoded)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')
autoencoder.summary()
# Out:
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 504, 128, 2)]     0
#
#  conv2d_31 (Conv2D)          (None, 504, 128, 4)       76
#
#  max_pooling2d_11 (MaxPoolin  (None, 252, 64, 4)       0
#  g2D)
#
#  conv2d_32 (Conv2D)          (None, 252, 64, 4)        148
#
#  up_sampling2d_11 (UpSamplin  (None, 504, 128, 4)      0
#  g2D)
#
#  conv2d_33 (Conv2D)          (None, 504, 128, 2)       74
#
# =================================================================
# Total params: 298
# Trainable params: 298
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.fit(audio,audio,
                epochs=100,
                batch_size=1,
                shuffle=False)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 32ms/step - loss: 3.2947e-04
# Epoch 2/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.2931e-04
# Epoch 3/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.2915e-04
# Epoch 4/100
# 1/1 [==============================] - 0s 32ms/step - loss: 3.2897e-04
# Epoch 5/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.2878e-04
# Epoch 6/100
# 1/1 [==============================] - 0s 28ms/step - loss: 3.2858e-04
# Epoch 7/100
# 1/1 [==============================] - 0s 28ms/step - loss: 3.2837e-04
# Epoch 8/100
# 1/1 [==============================] - 0s 27ms/step - loss: 3.2815e-04
# Epoch 9/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.2796e-04
# Epoch 10/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.2776e-04
# Epoch 11/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.2761e-04
# Epoch 12/100
# 1/1 [==============================] - 0s 28ms/step - loss: 3.2746e-04
# Epoch 13/100
# 1/1 [==============================] - 0s 27ms/step - loss: 3.2727e-04
# Epoch 14/100
# 1/1 [==============================] - 0s 27ms/step - loss: 3.2705e-04
# Epoch 15/100
# 1/1 [==============================] - 0s 27ms/step - loss: 3.2686e-04
# Epoch 16/100
# 1/1 [==============================] - 0s 27ms/step - loss: 3.2667e-04
# Epoch 17/100
# 1/1 [==============================] - 0s 28ms/step - loss: 3.2650e-04
# Epoch 18/100
# 1/1 [==============================] - 0s 27ms/step - loss: 3.2634e-04
# Epoch 19/100
# 1/1 [==============================] - 0s 28ms/step - loss: 3.2617e-04
# Epoch 20/100
# 1/1 [==============================] - 0s 28ms/step - loss: 3.2601e-04
# Epoch 21/100
# 1/1 [==============================] - 0s 27ms/step - loss: 3.2584e-04
# Epoch 22/100
# 1/1 [==============================] - 0s 28ms/step - loss: 3.2567e-04
# Epoch 23/100
# 1/1 [==============================] - 0s 27ms/step - loss: 3.2549e-04
# Epoch 24/100
# 1/1 [==============================] - 0s 28ms/step - loss: 3.2533e-04
# Epoch 25/100
# 1/1 [==============================] - 0s 27ms/step - loss: 3.2516e-04
# Epoch 26/100
# 1/1 [==============================] - 0s 28ms/step - loss: 3.2499e-04
# Epoch 27/100
# 1/1 [==============================] - 0s 28ms/step - loss: 3.2482e-04
# Epoch 28/100
# 1/1 [==============================] - 0s 26ms/step - loss: 3.2465e-04
# Epoch 29/100
# 1/1 [==============================] - 0s 27ms/step - loss: 3.2448e-04
# Epoch 30/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.2430e-04
# Epoch 31/100
# 1/1 [==============================] - 0s 32ms/step - loss: 3.2412e-04
# Epoch 32/100
# 1/1 [==============================] - 0s 32ms/step - loss: 3.2394e-04
# Epoch 33/100
# 1/1 [==============================] - 0s 33ms/step - loss: 3.2377e-04
# Epoch 34/100
# 1/1 [==============================] - 0s 36ms/step - loss: 3.2358e-04
# Epoch 35/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.2340e-04
# Epoch 36/100
# 1/1 [==============================] - 0s 28ms/step - loss: 3.2322e-04
# Epoch 37/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.2303e-04
# Epoch 38/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.2285e-04
# Epoch 39/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.2266e-04
# Epoch 40/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.2246e-04
# Epoch 41/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.2227e-04
# Epoch 42/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.2207e-04
# Epoch 43/100
# 1/1 [==============================] - 0s 33ms/step - loss: 3.2188e-04
# Epoch 44/100
# 1/1 [==============================] - 0s 32ms/step - loss: 3.2168e-04
# Epoch 45/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.2148e-04
# Epoch 46/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.2128e-04
# Epoch 47/100
# 1/1 [==============================] - 0s 32ms/step - loss: 3.2107e-04
# Epoch 48/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.2086e-04
# Epoch 49/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.2067e-04
# Epoch 50/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.2046e-04
# Epoch 51/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.2025e-04
# Epoch 52/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.2005e-04
# Epoch 53/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.1985e-04
# Epoch 54/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.1964e-04
# Epoch 55/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.1944e-04
# Epoch 56/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.1923e-04
# Epoch 57/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.1903e-04
# Epoch 58/100
# 1/1 [==============================] - 0s 33ms/step - loss: 3.1883e-04
# Epoch 59/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.1862e-04
# Epoch 60/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.1841e-04
# Epoch 61/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.1821e-04
# Epoch 62/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.1801e-04
# Epoch 63/100
# 1/1 [==============================] - 0s 28ms/step - loss: 3.1780e-04
# Epoch 64/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.1759e-04
# Epoch 65/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.1738e-04
# Epoch 66/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.1717e-04
# Epoch 67/100
# 1/1 [==============================] - 0s 28ms/step - loss: 3.1695e-04
# Epoch 68/100
# 1/1 [==============================] - 0s 32ms/step - loss: 3.1674e-04
# Epoch 69/100
# 1/1 [==============================] - 0s 32ms/step - loss: 3.1653e-04
# Epoch 70/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.1632e-04
# Epoch 71/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.1610e-04
# Epoch 72/100
# 1/1 [==============================] - 0s 28ms/step - loss: 3.1589e-04
# Epoch 73/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.1567e-04
# Epoch 74/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.1544e-04
# Epoch 75/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.1522e-04
# Epoch 76/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.1501e-04
# Epoch 77/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.1480e-04
# Epoch 78/100
# 1/1 [==============================] - 0s 28ms/step - loss: 3.1458e-04
# Epoch 79/100
# 1/1 [==============================] - 0s 28ms/step - loss: 3.1436e-04
# Epoch 80/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.1414e-04
# Epoch 81/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.1392e-04
# Epoch 82/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.1370e-04
# Epoch 83/100
# 1/1 [==============================] - 0s 32ms/step - loss: 3.1348e-04
# Epoch 84/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.1325e-04
# Epoch 85/100
# 1/1 [==============================] - 0s 42ms/step - loss: 3.1303e-04
# Epoch 86/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.1281e-04
# Epoch 87/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.1257e-04
# Epoch 88/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.1234e-04
# Epoch 89/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.1211e-04
# Epoch 90/100
# 1/1 [==============================] - 0s 33ms/step - loss: 3.1189e-04
# Epoch 91/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.1165e-04
# Epoch 92/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.1142e-04
# Epoch 93/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.1119e-04
# Epoch 94/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.1096e-04
# Epoch 95/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.1074e-04
# Epoch 96/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.1052e-04
# Epoch 97/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.1029e-04
# Epoch 98/100
# 1/1 [==============================] - 0s 29ms/step - loss: 3.1007e-04
# Epoch 99/100
# 1/1 [==============================] - 0s 30ms/step - loss: 3.0984e-04
# Epoch 100/100
# 1/1 [==============================] - 0s 27ms/step - loss: 3.0962e-04

# %%
import IPython

decoded_array = autoencoder.predict(audio)[0]
decoded_audio = irosaspec(decoded_array,NFFT)

enprobe = rosaspec(yoriginal, NFFT)
deprobe = irosaspec(enprobe,NFFT)

noisy = yoriginal+np.random.normal(0,0.01,64000)
ennoisy = rosaspec(noisy, NFFT)
denoisy = irosaspec(ennoisy,NFFT)

import matplotlib.pyplot as plt
from librosa import display
plt.figure()
plt.subplot(1, 2, 2) 
lr.display.waveplot(y=decoded_audio,sr=sroriginal)
plt.subplot(1, 2, 1) 
lr.display.waveplot(y=yoriginal,sr=sroriginal)
plt.show()


#IPython.display.display(IPython.display.Audio(file))
IPython.display.display(IPython.display.Audio(deprobe,rate = sroriginal))
#IPython.display.display(IPython.display.Audio(deprobe,rate=sroriginal))
#IPython.display.display(IPython.display.Audio(noisy,rate=sroriginal))
#IPython.display.display(IPython.display.Audio(denoisy,rate=sroriginal))
IPython.display.display(IPython.display.Audio(decoded_audio,rate=sroriginal))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from scipy.signal import butter, lfilter, freqz

def butter_lowpass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return b, a

def butter_lowpass_filter(data, cutoff, fs, order=5):
    b, a = butter_lowpass(cutoff, fs, order=order)
    y = lfilter(b, a, data)
    return y


# Setting standard filter requirements.
order = 6
fs = 30.0       
cutoff = 14.7

b, a = butter_lowpass(cutoff, fs, order)

filtered = butter_lowpass_filter(decoded_audio, cutoff, fs, order)
plt.figure()
plt.subplot(1, 2, 2) 
lr.display.waveplot(y=filtered,sr=sroriginal)
plt.subplot(1, 2, 1) 
lr.display.waveplot(y=yoriginal,sr=sroriginal)
plt.show()

IPython.display.display(IPython.display.Audio(deprobe,rate=sroriginal))
IPython.display.display(IPython.display.Audio(filtered,rate=sroriginal))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio.max(), audio.min()
# Out:
# (1.0, -0.856759766190995)

# %%
print(yoriginal.shape)
print(enprobe.shape)
print(deprobe.shape)
print(decoded_array.shape)
print(decoded_audio.shape)
# Out:
# (64000,)
# (504, 128, 2)
# (63881,)
# (504, 128, 2)
# (63881,)

# %%
# Out:
# (1.0, -0.7587283885818327)

# %%
i = 2
j = 4
while i<25600/2:
    NFFT = i
    file = 'C:/Users/erikv/Desktop/IP/samples/bass_electronic_027-056-050.wav'

    yoriginal,sroriginal = lr.load(file,sr=None)
    orginalspect = lr.stft(yoriginal, n_fft=NFFT, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)
    audio = np.array([rosaspec(yoriginal,NFFT)])

    numbers = audio.shape
    x = numbers[1]
    y = numbers[2]
    if x%j == 0 and y%j == 0:
            print (i)
    i=i+2
# Out:
# 110
# 126
# 134
# 166
# 174
# 182
# 254
# 286
# 294
# 302
# 334
# 382
# 406
# 422
# 478
# 486
# 494
# 518
# 526
# 534
# 582
# 606
# 630
# 654
# 670
# 766
# 782
# 822
# 846
# 870
# 894
# 918
# 942
# 974
# 1006
# 1038
# 1070
# 1110
# 1150
# 1190
# 1238
# 1286
# 1334
# 1342
# 1398
# 1406
# 1462
# 1470
# 1526
# 1534
# 1542
# 1606
# 1614
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5012/1441324705.py in <module>
#       7     yoriginal,sroriginal = lr.load(file,sr=None)
#       8     orginalspect = lr.stft(yoriginal, n_fft=NFFT, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)
# ----> 9     audio = np.array([rosaspec(yoriginal,NFFT)])
#      10
#      11     numbers = audio.shape
#
# ~\AppData\Local\Temp/ipykernel_5012/3004960298.py in rosaspec(sound, NFFT)
#       6 def rosaspec(sound, NFFT):
#       7     sound = np.concatenate((np.zeros(int(NFFT/2)),sound,np.zeros(int(NFFT/2))))
# ----> 8     spec_c = lr.stft(sound, n_fft=NFFT, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)
#       9     return np.concatenate((np.expand_dims(np.real(spec_c),2),np.expand_dims(np.imag(spec_c),2)),axis=2)
#      10
#
# C:\ProgramData\Anaconda3\lib\site-packages\librosa\core\spectrum.py in stft(y, n_fft, hop_length, win_length, window, center, dtype, pad_mode)
#     255         bl_t = min(bl_s + n_columns, stft_matrix.shape[1])
#     256
# --> 257         stft_matrix[:, bl_s:bl_t] = fft.rfft(
#     258             fft_window * y_frames[:, bl_s:bl_t], axis=0
#     259         )
#
# KeyboardInterrupt:
