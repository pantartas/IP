# %%
# %%javascript
#
# window.scroll_flag = true
# window.scroll_exit = false
# window.scroll_delay = 100
#
# $(".output_scroll").each(function() {
#     $(this)[0].scrollTop = $(this)[0].scrollHeight;
# });
#
# function callScrollToBottom() {
#     setTimeout(scrollToBottom, window.scroll_delay);
# }
#
# function scrollToBottom() {
#     if (window.scroll_exit) {
#         return;
#     }
#     if (!window.scroll_flag) {
#         callScrollToBottom();
#         return;
#     };
#
#     $(".output_scroll").each(function() {
#         if (!$(this).attr('scroll_checkbox')){
#             window.scroll_flag = true;
#             $(this).attr('scroll_checkbox',true);
#             var div = document.createElement('div');
#             var checkbox = document.createElement('input');
#             checkbox.type = "checkbox";
#             checkbox.onclick = function(){window.scroll_flag = checkbox.checked}
#             checkbox.checked = "checked"
#             div.append("Auto-Scroll-To-Bottom: ");
#             div.append(checkbox);
#             $(this).parent().before(div);
#         }
#
#         $(this)[0].scrollTop = $(this)[0].scrollHeight;
#     });
#     callScrollToBottom();
# }
# scrollToBottom();

# %%
import os
import IPython
import keras_tuner as kt
import librosa as lr
import numpy as np
from datetime import datetime
from packaging import version
import tensorboard
import keras
from keras import layers
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt
from librosa import display
from tensorflow.keras.layers import Conv2D,MaxPooling2D,UpSampling2D
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters
import time

LOG_DIR = f'{int(time.time())}'

path = 'C:/Users/erikv/Desktop/IP/samples/' 
dirs = os.listdir(path)
#IPython.display.display(IPython.display.Audio(path+dirs[3],rate=sroriginal))

def rosaspec(sound, NFFT):
    sound = np.concatenate((np.zeros(int(NFFT/2)),sound,np.zeros(int(NFFT/2))))
    spec_c = lr.stft(sound, n_fft=NFFT, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)
    return np.concatenate((np.expand_dims(np.real(spec_c),2),np.expand_dims(np.imag(spec_c),2)),axis=2)

def irosaspec(spec,NFFT):
    spec_c = spec[:,:,0].squeeze() + 1j* spec[:,:,1].squeeze()
    return lr.istft(spec_c, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)[int(NFFT/2):-int(NFFT/2)]
#use a rectangular window.

# %%
NFFT = int(1021/2)
yoriginal1,sroriginal1 = lr.load(path+dirs[9],sr=2000)
originalspect = lr.stft(yoriginal1, n_fft=NFFT, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)
asignal = np.array([rosaspec(yoriginal1,NFFT)])
test = asignal/asignal.max()

print (test.shape)
# Out:
# (1, 256, 32, 2)

# %%
batchsize = 10 #len(dirs)
processed = np.zeros([batchsize, 256, 32, 2])
for i in range(batchsize):
    yoriginal,sroriginal = lr.load(path+dirs[i],sr=2000)
    originalspect = lr.stft(yoriginal, n_fft=NFFT, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)
    asignal = np.array([rosaspec(yoriginal,NFFT)])
    audio = asignal/asignal.max()
    processed[i] = audio

print (audio.shape,processed.shape)
# Out:
# (1, 256, 32, 2) (10, 256, 32, 2)

# %%
device = 'cuda'
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print(test[0,66,26,0])
print(processed[9,66,26,0])
# Out:
# Num GPUs Available:  1
# -1.824749499151583e-06
# -1.824749499151583e-06

# %%
input_shape = (processed.shape)
inp = (input_shape[1],input_shape[2],input_shape[3])
def build_model(hp):
    model = keras.models.Sequential()
    model.add(Conv2D(hp.Int("input_units",4,64,4), (3,3), activation='LeakyReLU', padding='same', input_shape=(inp)))

    model.add(Conv2D(hp.Int("1layer",4,64,4),(3,3),activation='LeakyReLU', padding='same'))
    model.add(MaxPooling2D((2, 2), padding='same'))
    model.add(Conv2D(hp.Int("2layer",4,64,4),(3,3),activation='LeakyReLU', padding='same'))
    model.add(MaxPooling2D((2, 2), padding='same'))
    model.add(Conv2D(hp.Int("3layer",4,64,4),(3,3),activation='LeakyReLU', padding='same'))
    model.add(MaxPooling2D((2, 2), padding='same'))
    model.add(Conv2D(hp.Int("4layer",4,64,4),(3,3),activation='LeakyReLU', padding='same'))
    model.add(MaxPooling2D((2, 2), padding='same'))
    
    model.add(Conv2D(hp.Int("layer1",4,64,4),(3,3),activation='LeakyReLU', padding='same'))
    model.add(UpSampling2D((2,2)))
    model.add(Conv2D(hp.Int("layer2",4,64,4),(3,3),activation='LeakyReLU', padding='same'))
    model.add(UpSampling2D((2,2)))
    model.add(Conv2D(hp.Int("layer3",4,64,4),(3,3),activation='LeakyReLU', padding='same'))
    model.add(UpSampling2D((2,2)))
    model.add(Conv2D(hp.Int("layer4",4,64,4),(3,3),activation='LeakyReLU', padding='same'))
    model.add(UpSampling2D((2,2)))
    
    model.add(Conv2D(2,(3,3),activation='LeakyReLU', padding='same'))

    model.compile(optimizer='adam', 
                  loss='mean_absolute_percentage_error',
                  metrics=['accuracy'])

    return model

# %%
tuner = RandomSearch(
    build_model,
    objective = 'val_accuracy',
    max_trials = 1,
    executions_per_trial = 100,
    directory = LOG_DIR)

tuner.search(x = processed,
             y = processed,
            epochs = 1,
            batch_size = 10,
            validation_data = (test,test))
# Out:
# Search: Running Trial #1
#
# Hyperparameter    |Value             |Best Value So Far
# input_units       |8                 |?
# 1layer            |28                |?
# 2layer            |52                |?
# 3layer            |60                |?
# 4layer            |28                |?
# layer1            |64                |?
# layer2            |8                 |?
# layer3            |48                |?
# layer4            |44                |?
#
# 1/1 [==============================] - 4s 4s/step - loss: 30963.2598 - accuracy: 0.4767 - val_loss: 259316.6562 - val_accuracy: 0.5508
# 1/1 [==============================] - 1s 1s/step - loss: 49658.6641 - accuracy: 0.4900 - val_loss: 456553.6250 - val_accuracy: 0.5497
# 1/1 [==============================] - 1s 1s/step - loss: 30302.6035 - accuracy: 0.5179 - val_loss: 593451.1875 - val_accuracy: 0.4504
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17432/992582837.py in <module>
#       6     directory = LOG_DIR)
#       7
# ----> 8 tuner.search(x = processed,
#       9              y = processed,
#      10             epochs = 1,
#
# ~\.conda\envs\keras\lib\site-packages\keras_tuner\engine\base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     177
#     178             self.on_trial_begin(trial)
# --> 179             results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     180             # `results` is None indicates user updated oracle in `run_trial()`.
#     181             if results is None:
#
# ~\.conda\envs\keras\lib\site-packages\keras_tuner\engine\tuner.py in run_trial(self, trial, *args, **kwargs)
#     302             callbacks.append(model_checkpoint)
#     303             copied_kwargs["callbacks"] = callbacks
# --> 304             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     305
#     306             # objective left unspecified,
#
# ~\.conda\envs\keras\lib\site-packages\keras_tuner\engine\tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#     232         hp = trial.hyperparameters
#     233         model = self._try_build(hp)
# --> 234         return self.hypermodel.fit(hp, model, *args, **kwargs)
#     235
#     236     def run_trial(self, trial, *args, **kwargs):
#
# ~\.conda\envs\keras\lib\site-packages\keras_tuner\engine\hypermodel.py in fit(self, hp, model, *args, **kwargs)
#     135             If return a float, it should be the `objective` value.
#     136         """
# --> 137         return model.fit(*args, **kwargs)
#     138
#     139
#
# ~\.conda\envs\keras\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     931       # This is the first call of __call__, so we have to initialize.
#     932       initializers = []
# --> 933       self._initialize(args, kwds, add_initializers_to=initializers)
#     934     finally:
#     935       # At this point we know that the initialization is complete (or less
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     757     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     758     self._concrete_stateful_fn = (
# --> 759         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     760             *args, **kwds))
#     761
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3064       args, kwargs = None, None
#    3065     with self._lock:
# -> 3066       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3067     return graph_function
#    3068
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3461
#    3462           self._function_cache.missed.add(call_context_key)
# -> 3463           graph_function = self._create_graph_function(args, kwargs)
#    3464           self._function_cache.primary[cache_key] = graph_function
#    3465
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3296     arg_names = base_arg_names + missing_arg_names
#    3297     graph_function = ConcreteFunction(
# -> 3298         func_graph_module.func_graph_from_py_func(
#    3299             self._name,
#    3300             self._python_function,
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1005         _, original_func = tf_decorator.unwrap(python_func)
#    1006
# -> 1007       func_outputs = python_func(*func_args, **func_kwargs)
#    1008
#    1009       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     666         # the function a weak reference to itself to avoid a reference cycle.
#     667         with OptionalXlaContext(compile_with_xla):
# --> 668           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     669         return out
#     670
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\framework\func_graph.py in wrapper(*args, **kwargs)
#     981           # TODO(mdan): Push this block higher in tf.function's call stack.
#     982           try:
# --> 983             return autograph.converted_call(
#     984                 original_func,
#     985                 args,
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# ~\.conda\envs\keras\lib\site-packages\keras\engine\training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     380
#     381   if not options.user_requested and conversion.is_allowlisted(f):
# --> 382     return _call_unconverted(f, args, kwargs, options)
#     383
#     384   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\autograph\impl\api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     462   if kwargs is not None:
#     463     return f(*args, **kwargs)
# --> 464   return f(*args)
#     465
#     466
#
# ~\.conda\envs\keras\lib\site-packages\keras\engine\training.py in step_function(model, iterator)
#     840
#     841       data = next(iterator)
# --> 842       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     843       outputs = reduce_per_replica(
#     844           outputs, self.distribute_strategy, reduction='first')
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in run(***failed resolving arguments***)
#    1284       fn = autograph.tf_convert(
#    1285           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1286       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1287
#    1288   def reduce(self, reduce_op, value, axis):
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2847       kwargs = {}
#    2848     with self._container_strategy().scope():
# -> 2849       return self._call_for_each_replica(fn, args, kwargs)
#    2850
#    2851   def _call_for_each_replica(self, fn, args, kwargs):
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    3630   def _call_for_each_replica(self, fn, args, kwargs):
#    3631     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3632       return fn(*args, **kwargs)
#    3633
#    3634   def _reduce_to(self, reduce_op, value, destinations, options):
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     690       try:
#     691         with conversion_ctx:
# --> 692           return converted_call(f, args, kwargs, options=options)
#     693       except Exception as e:  # pylint:disable=broad-except
#     694         if hasattr(e, 'ag_error_metadata'):
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     380
#     381   if not options.user_requested and conversion.is_allowlisted(f):
# --> 382     return _call_unconverted(f, args, kwargs, options)
#     383
#     384   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\autograph\impl\api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     461
#     462   if kwargs is not None:
# --> 463     return f(*args, **kwargs)
#     464   return f(*args)
#     465
#
# ~\.conda\envs\keras\lib\site-packages\keras\engine\training.py in run_step(data)
#     833
#     834       def run_step(data):
# --> 835         outputs = model.train_step(data)
#     836         # Ensure counter is updated only if `train_step` succeeds.
#     837         with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# ~\.conda\envs\keras\lib\site-packages\keras\engine\training.py in train_step(self, data)
#     785     # Run forward pass.
#     786     with tf.GradientTape() as tape:
# --> 787       y_pred = self(x, training=True)
#     788       loss = self.compiled_loss(
#     789           y, y_pred, sample_weight, regularization_losses=self.losses)
#
# ~\.conda\envs\keras\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# ~\.conda\envs\keras\lib\site-packages\keras\engine\sequential.py in call(self, inputs, training, mask)
#     367       if not self.built:
#     368         self._init_graph_network(self.inputs, self.outputs)
# --> 369       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     370
#     371     outputs = inputs  # handle the corner case where self.layers is empty
#
# ~\.conda\envs\keras\lib\site-packages\keras\engine\functional.py in call(self, inputs, training, mask)
#     412         a list of tensors if there are more than one outputs.
#     413     """
# --> 414     return self._run_internal_graph(
#     415         inputs, training=training, mask=mask)
#     416
#
# ~\.conda\envs\keras\lib\site-packages\keras\engine\functional.py in _run_internal_graph(self, inputs, training, mask)
#     548
#     549         args, kwargs = node.map_arguments(tensor_dict)
# --> 550         outputs = node.layer(*args, **kwargs)
#     551
#     552         # Update tensor_dict.
#
# ~\.conda\envs\keras\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# ~\.conda\envs\keras\lib\site-packages\keras\layers\convolutional.py in call(self, inputs)
#     274
#     275     if self.activation is not None:
# --> 276       return self.activation(outputs)
#     277     return outputs
#     278
#
# ~\.conda\envs\keras\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# ~\.conda\envs\keras\lib\site-packages\keras\layers\advanced_activations.py in call(self, inputs)
#      75
#      76   def call(self, inputs):
# ---> 77     return backend.relu(inputs, alpha=self.alpha)
#      78
#      79   def get_config(self):
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\.conda\envs\keras\lib\site-packages\keras\backend.py in relu(x, alpha, max_value, threshold)
#    4693   if alpha != 0.:
#    4694     if max_value is None and threshold == 0:
# -> 4695       return tf.nn.leaky_relu(x, alpha=alpha)
#    4696
#    4697     if threshold != 0:
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\ops\nn_ops.py in leaky_relu(features, alpha, name)
#    3619     if isinstance(alpha, np.ndarray):
#    3620       alpha = alpha.item()
# -> 3621     return gen_nn_ops.leaky_relu(features, alpha=alpha, name=name)
#    3622
#    3623
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\ops\gen_nn_ops.py in leaky_relu(features, alpha, name)
#    5115     alpha = 0.2
#    5116   alpha = _execute.make_float(alpha, "alpha")
# -> 5117   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    5118         "LeakyRelu", features=features, alpha=alpha, name=name)
#    5119   _result = _outputs[:]
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     746       # Add Op to graph
#     747       # pylint: disable=protected-access
# --> 748       op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     749                                  name=scope, input_types=input_types,
#     750                                  attrs=attr_protos, op_def=op_def)
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\framework\func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     597       inp = self.capture(inp)
#     598       captured_inputs.append(inp)
# --> 599     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     600         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     601         compute_device)
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\framework\ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3568           original_op=self._default_original_op,
#    3569           op_def=op_def)
# -> 3570       self._create_op_helper(ret, compute_device=compute_device)
#    3571     return ret
#    3572
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\framework\ops.py in _create_op_helper(self, op, compute_device)
#    3629       pass
#    3630
# -> 3631     op._gradient_function = self._gradient_function_map.get(op.type)  # pylint: disable=protected-access
#    3632
#    3633     # Apply the overriding op type for gradients if one has been specified for
#
# ~\.conda\envs\keras\lib\site-packages\tensorflow\python\framework\ops.py in type(self)
#    2451   def type(self):
#    2452     """The type of the op (e.g. `"MatMul"`)."""
# -> 2453     return pywrap_tf_session.TF_OperationOpType(self._c_op)
#    2454
#    2455   @property
#
# KeyboardInterrupt:

# %%
print(tuner.results_summary())
# Out:
# Results summary
# Results in 1643762867\untitled_project
# Showing 10 best trials
# Objective(name='val_accuracy', direction='max')
# Trial summary
# Hyperparameters:
# input_units: 60
# 1layer: 16
# 2layer: 12
# 3layer: 16
# 4layer: 56
# layer1: 28
# layer2: 24
# layer3: 16
# layer4: 60
# Score: 0.50447265625
# None

# %%
print(tuner.get_best_models()[0].summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 32, 60)       1140
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 32, 16)       8656
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 16, 16)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 16, 12)       1740
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 8, 12)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 8, 16)         1744
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 4, 16)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 4, 56)         8120
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 2, 56)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 2, 28)         14140
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 32, 4, 28)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 4, 24)         6072
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 64, 8, 24)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 64, 8, 16)         3472
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 128, 16, 16)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 128, 16, 60)       8700
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 256, 32, 60)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 256, 32, 2)        1082
# =================================================================
# Total params: 54,866
# Trainable params: 54,866
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# None

# %%
def build_model_tuned(x,a1,a2,a3,a4,b1,b2,b3,b4):
    model = keras.models.Sequential()
    model = keras.models.Sequential()
    model.add(Conv2D(x, (3,3), activation='LeakyReLU', padding='same', input_shape=(inp)))

    model.add(Conv2D(a1,(3,3),activation='LeakyReLU', padding='same'))
    model.add(MaxPooling2D((2, 2), padding='same'))
    model.add(Conv2D(a2,(3,3),activation='LeakyReLU', padding='same'))
    model.add(MaxPooling2D((2, 2), padding='same'))
    model.add(Conv2D(a3,(3,3),activation='LeakyReLU', padding='same'))
    model.add(MaxPooling2D((2, 2), padding='same'))
    model.add(Conv2D(a4,(3,3),activation='LeakyReLU', padding='same'))
    model.add(MaxPooling2D((2, 2), padding='same'))
    
    model.add(Conv2D(b1,(3,3),activation='LeakyReLU', padding='same'))
    model.add(UpSampling2D((2,2)))
    model.add(Conv2D(b2,(3,3),activation='LeakyReLU', padding='same'))
    model.add(UpSampling2D((2,2)))
    model.add(Conv2D(b3,(3,3),activation='LeakyReLU', padding='same'))
    model.add(UpSampling2D((2,2)))
    model.add(Conv2D(b4,(3,3),activation='LeakyReLU', padding='same'))
    model.add(UpSampling2D((2,2)))
    
    model.add(Conv2D(2,(3,3),activation='LeakyReLU', padding='same'))

    model.compile(optimizer='adam', 
                  loss='mean_absolute_percentage_error',
                  metrics=['accuracy'])

    return model

# %%
print(tuner.get_best_hyperparameters()[0].values)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17432/1224631856.py in <module>
# ----> 1 print(tuner.get_best_hyperparameters()[0].values)
#
# IndexError: list index out of range

# %%
autoencoder = build_model_tuned(256,256,512,512,1024,1024,512,512,256)
print(autoencoder.summary())
print(tuner.get_best_models()[0].summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 256, 32, 256)      4864
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 256, 32, 256)      590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 128, 16, 256)      0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 128, 16, 512)      1180160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 64, 8, 512)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 64, 8, 512)        2359808
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 32, 4, 512)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 32, 4, 1024)       4719616
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 16, 2, 1024)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 16, 2, 1024)       9438208
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 32, 4, 1024)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 32, 4, 512)        4719104
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 64, 8, 512)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 64, 8, 512)        2359808
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 128, 16, 512)      0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 128, 16, 256)      1179904
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 256, 32, 256)      0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 256, 32, 2)        4610
# =================================================================
# Total params: 26,556,162
# Trainable params: 26,556,162
# Non-trainable params: 0
# _________________________________________________________________
# None
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17432/406335230.py in <module>
#       1 autoencoder = build_model_tuned(256,256,512,512,1024,1024,512,512,256)
#       2 print(autoencoder.summary())
# ----> 3 print(tuner.get_best_models()[0].summary())
#
# IndexError: list index out of range

# %%
autoencoder.fit(processed,processed,
                epochs=10,
                batch_size=1,
                shuffle=False,
                validation_data=(test,test))
# Out:
# Epoch 1/10
# 10/10 [==============================] - 1s 81ms/step - loss: 507569.5938 - accuracy: 0.5000 - val_loss: 335220.2500 - val_accuracy: 0.5247
# Epoch 2/10
# 10/10 [==============================] - 1s 76ms/step - loss: 185557.9688 - accuracy: 0.4972 - val_loss: 149736.5625 - val_accuracy: 0.4673
# Epoch 3/10
# 10/10 [==============================] - 1s 76ms/step - loss: 133767.0312 - accuracy: 0.4970 - val_loss: 147108.9375 - val_accuracy: 0.4563
# Epoch 4/10
# 10/10 [==============================] - 1s 76ms/step - loss: 160281.7344 - accuracy: 0.4934 - val_loss: 147319.3906 - val_accuracy: 0.5491
# Epoch 5/10
# 10/10 [==============================] - 1s 76ms/step - loss: 156965.2031 - accuracy: 0.4955 - val_loss: 178871.2500 - val_accuracy: 0.5455
# Epoch 6/10
# 10/10 [==============================] - 1s 77ms/step - loss: 103870.7031 - accuracy: 0.5040 - val_loss: 93783.3672 - val_accuracy: 0.4894
# Epoch 7/10
# 10/10 [==============================] - 1s 77ms/step - loss: 79661.9766 - accuracy: 0.5010 - val_loss: 75205.5391 - val_accuracy: 0.5167
# Epoch 8/10
# 10/10 [==============================] - 1s 76ms/step - loss: 57868.2305 - accuracy: 0.5038 - val_loss: 53931.8555 - val_accuracy: 0.4969
# Epoch 9/10
# 10/10 [==============================] - 1s 77ms/step - loss: 51386.0938 - accuracy: 0.4994 - val_loss: 71391.5547 - val_accuracy: 0.5100
# Epoch 10/10
# 10/10 [==============================] - 1s 78ms/step - loss: 68200.0234 - accuracy: 0.4904 - val_loss: 56960.9219 - val_accuracy: 0.4586

# %%
decoded_array = autoencoder.predict(processed)[9]
decoded_audio = irosaspec(decoded_array,NFFT)

enprobe = rosaspec(yoriginal1, NFFT)
deprobe = irosaspec(enprobe,NFFT)

#noisy = yoriginal+np.random.normal(0,0.01,64000)
#ennoisy = rosaspec(noisy, NFFT)
#denoisy = irosaspec(ennoisy,NFFT)

plt.figure()
plt.subplot(1, 2, 2) 
lr.display.waveplot(y=decoded_audio,sr=sroriginal)
plt.subplot(1, 2, 1) 
lr.display.waveplot(y=yoriginal1,sr=sroriginal)
plt.show()

#IPython.display.display(IPython.display.Audio(file))
IPython.display.display(IPython.display.Audio(deprobe,rate = sroriginal))
#IPython.display.display(IPython.display.Audio(noisy,rate=sroriginal))
#IPython.display.display(IPython.display.Audio(denoisy,rate=sroriginal))
IPython.display.display(IPython.display.Audio(decoded_audio,rate=sroriginal))

print(test[0,66,26,1])
print(decoded_array[66,26,1])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 4.904363271025028e-07
# 0.014672095

# %%
from scipy.signal import butter, lfilter, freqz

def butter_lowpass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return b, a

def butter_lowpass_filter(data, cutoff, fs, order=5):
    b, a = butter_lowpass(cutoff, fs, order=order)
    y = lfilter(b, a, data)
    return y


# Setting standard filter requirements.
order = 6
fs = 30.0       
cutoff = 13

b, a = butter_lowpass(cutoff, fs, order)

filtered1 = butter_lowpass_filter(yoriginal1, cutoff, fs, order)
filtered = butter_lowpass_filter(decoded_audio, cutoff, fs, order)
plt.figure()
plt.subplot(1, 2, 2) 
lr.display.waveplot(y=filtered,sr=sroriginal)
plt.subplot(1, 2, 1) 
lr.display.waveplot(y=yoriginal1,sr=sroriginal)
plt.show()

IPython.display.display(IPython.display.Audio(yoriginal1,rate=sroriginal))
IPython.display.display(IPython.display.Audio(filtered,rate=sroriginal))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio.max(), audio.min()
# Out:
# (1.0, -0.856759766190995)

# %%
print(yoriginal.shape)
print(enprobe.shape)
print(deprobe.shape)
print(decoded_array.shape)
print(decoded_audio.shape)
# Out:
# (64000,)
# (504, 128, 2)
# (63881,)
# (504, 128, 2)
# (63881,)

# %%
# Out:
# (1.0, -0.7587283885818327)

# %%
i = 2
j = 4
while i<25600/2:
    NFFT = i
    file = 'C:/Users/erikv/Desktop/IP/samples/bass_electronic_027-056-050.wav'

    yoriginal,sroriginal = lr.load(file,sr=None)
    orginalspect = lr.stft(yoriginal, n_fft=NFFT, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)
    audio = np.array([rosaspec(yoriginal,NFFT)])

    numbers = audio.shape
    x = numbers[1]
    y = numbers[2]
    if x%j == 0 and y%j == 0:
            print (i)
    i=i+2
# Out:
# 110
# 126
# 134
# 166
# 174
# 182
# 254
# 286
# 294
# 302
# 334
# 382
# 406
# 422
# 478
# 486
# 494
# 518
# 526
# 534
# 582
# 606
# 630
# 654
# 670
# 766
# 782
# 822
# 846
# 870
# 894
# 918
# 942
# 974
# 1006
# 1038
# 1070
# 1110
# 1150
# 1190
# 1238
# 1286
# 1334
# 1342
# 1398
# 1406
# 1462
# 1470
# 1526
# 1534
# 1542
# 1606
# 1614
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5012/1441324705.py in <module>
#       7     yoriginal,sroriginal = lr.load(file,sr=None)
#       8     orginalspect = lr.stft(yoriginal, n_fft=NFFT, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)
# ----> 9     audio = np.array([rosaspec(yoriginal,NFFT)])
#      10
#      11     numbers = audio.shape
#
# ~\AppData\Local\Temp/ipykernel_5012/3004960298.py in rosaspec(sound, NFFT)
#       6 def rosaspec(sound, NFFT):
#       7     sound = np.concatenate((np.zeros(int(NFFT/2)),sound,np.zeros(int(NFFT/2))))
# ----> 8     spec_c = lr.stft(sound, n_fft=NFFT, hop_length=int(NFFT/2), win_length=None, window='hann', center=False)
#       9     return np.concatenate((np.expand_dims(np.real(spec_c),2),np.expand_dims(np.imag(spec_c),2)),axis=2)
#      10
#
# C:\ProgramData\Anaconda3\lib\site-packages\librosa\core\spectrum.py in stft(y, n_fft, hop_length, win_length, window, center, dtype, pad_mode)
#     255         bl_t = min(bl_s + n_columns, stft_matrix.shape[1])
#     256
# --> 257         stft_matrix[:, bl_s:bl_t] = fft.rfft(
#     258             fft_window * y_frames[:, bl_s:bl_t], axis=0
#     259         )
#
# KeyboardInterrupt:
